# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()
system.portfolio.get_notional_position("EDOLLAR")
# Out:
# 2023-01-13 14:14:46 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2023-01-13 14:14:46 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2023-01-13 14:14:46 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2023-01-13 14:14:46 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2023-01-13 14:14:46 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating notional position for EDOLLAR
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument weights
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'portfolio'}  Calculating raw instrument weights
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2023-01-13 14:14:46 {'type': 'base_system'}  Following instruments marked as not trading []
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating subsystem position for CORN
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating volatility scalar for CORN
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument value vol for CORN
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument currency vol for CORN
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily volatility for CORN
# 2023-01-13 14:14:46 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating combined forecast for CORN
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating capped forecast for CORN carry
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating raw forecast CORN for carry
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for CORN ewmac16_64
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast CORN for ewmac16_64
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for CORN ewmac32_128
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast CORN for ewmac32_128
# 2023-01-13 14:14:47 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for CORN ewmac64_256
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast CORN for ewmac64_256
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating forecast weights for CORN
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for CORN {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating capped forecast for EDOLLAR carry
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating raw forecast EDOLLAR for carry
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily volatility for EDOLLAR
# 2023-01-13 14:14:48 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2023-01-13 14:14:49 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating capped forecast for EUROSTX carry
# 2023-01-13 14:14:49 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating raw forecast EUROSTX for carry
# 2023-01-13 14:14:49 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily volatility for EUROSTX
# 2023-01-13 14:14:49 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2023-01-13 14:14:49 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating capped forecast for MXP carry
# 2023-01-13 14:14:49 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating raw forecast MXP for carry
# 2023-01-13 14:14:50 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily volatility for MXP
# 2023-01-13 14:14:50 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2023-01-13 14:14:50 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating capped forecast for US10 carry
# 2023-01-13 14:14:50 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating raw forecast US10 for carry
# 2023-01-13 14:14:50 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily volatility for US10
# 2023-01-13 14:14:50 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2023-01-13 14:14:51 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating capped forecast for V2X carry
# 2023-01-13 14:14:51 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating raw forecast V2X for carry
# 2023-01-13 14:14:51 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily volatility for V2X
# 2023-01-13 14:14:51 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EDOLLAR ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EDOLLAR for ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EUROSTX ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EUROSTX for ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for MXP ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast MXP for ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for US10 ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast US10 for ewmac16_64
# 2023-01-13 14:14:52 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for V2X ewmac16_64
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast V2X for ewmac16_64
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EDOLLAR ewmac32_128
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EDOLLAR for ewmac32_128
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EUROSTX ewmac32_128
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EUROSTX for ewmac32_128
# 2023-01-13 14:14:53 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for MXP ewmac32_128
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast MXP for ewmac32_128
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for US10 ewmac32_128
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast US10 for ewmac32_128
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for V2X ewmac32_128
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast V2X for ewmac32_128
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EDOLLAR ewmac64_256
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EDOLLAR for ewmac64_256
# 2023-01-13 14:14:54 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EUROSTX ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EUROSTX for ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for MXP ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast MXP for ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for US10 ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast US10 for ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for V2X ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast V2X for ewmac64_256
# 2023-01-13 14:14:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Using fixed FDM multiplier of 1.310 for CORN
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  No mapping applied for CORN
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating subsystem position for EDOLLAR
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating volatility scalar for EDOLLAR
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument value vol for EDOLLAR
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument currency vol for EDOLLAR
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating combined forecast for EDOLLAR
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating forecast weights for EDOLLAR
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for EDOLLAR {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2023-01-13 14:14:56 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EDOLLAR
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Using fixed FDM multiplier of 1.310 for EDOLLAR
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  No mapping applied for EDOLLAR
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating subsystem position for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating volatility scalar for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument value vol for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument currency vol for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating combined forecast for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating forecast weights for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for EUROSTX {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Using fixed FDM multiplier of 1.310 for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  No mapping applied for EUROSTX
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating subsystem position for MXP
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating volatility scalar for MXP
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument value vol for MXP
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument currency vol for MXP
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating combined forecast for MXP
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating forecast weights for MXP
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for MXP {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2023-01-13 14:14:57 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Using fixed FDM multiplier of 1.310 for MXP
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  No mapping applied for MXP
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating subsystem position for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating volatility scalar for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument value vol for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument currency vol for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating combined forecast for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating forecast weights for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for US10 {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Using fixed FDM multiplier of 1.310 for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  No mapping applied for US10
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating subsystem position for V2X
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating volatility scalar for V2X
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument value vol for V2X
# 2023-01-13 14:14:58 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument currency vol for V2X
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating combined forecast for V2X
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating forecast weights for V2X
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for V2X {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Using fixed FDM multiplier of 1.310 for V2X
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  No mapping applied for V2X
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'portfolio'}  Using fixed diversification multiplier 1.890000
# 2023-01-13 14:14:59 {'type': 'base_system', 'stage': 'portfolio'}  No risk overlay in config: won't apply risk scaling
# index
# 1984-03-23         NaN
# 1984-03-26         NaN
# 1984-03-27         NaN
# 1984-03-28         NaN
# 1984-03-29         NaN
#                 ...
# 2022-10-25   -3.588912
# 2022-10-26   -3.509487
# 2022-10-27   -3.398191
# 2022-10-28   -3.298185
# 2022-10-31   -3.408957
# Freq: B, Length: 10072, dtype: float64

# %%
from systems.provided.futures_chapter15.estimatedsystem import futures_system
system=futures_system()
system.set_logging_level("on")
system.portfolio.get_notional_position("EDOLLAR")
# Out:
# 2022-11-28 11:33:41 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:33:41 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:33:41 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:33:41 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:33:41 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating notional position for EDOLLAR
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument weights
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2022-11-28 11:33:41 {'type': 'base_system'}  Following instruments marked as not trading []
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for subsystem for instrument CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating subsystem position for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating volatility scalar for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument value vol for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument currency vol for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily volatility for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating combined forecast for CORN
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating capped forecast for CORN carry
# 2022-11-28 11:33:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating raw forecast CORN for carry
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'carry'}  Getting cross sectional forecasts for scalar calculation for carry over CORN, EDOLLAR, EUROSTX, MXP, US10, V2X
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating raw forecast EDOLLAR for carry
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily volatility for EDOLLAR
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating raw forecast EUROSTX for carry
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily volatility for EUROSTX
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:33:42 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating raw forecast MXP for carry
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily volatility for MXP
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating raw forecast US10 for carry
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily volatility for US10
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating raw forecast V2X for carry
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily volatility for V2X
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for CORN ewmac16_64
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast CORN for ewmac16_64
# 2022-11-28 11:33:43 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# /home/arto/anaconda3/envs/pysystemtrade385/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac16_64'}  Getting cross sectional forecasts for scalar calculation for ewmac16_64 over CORN, EDOLLAR, EUROSTX, MXP, US10, V2X
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EDOLLAR for ewmac16_64
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EUROSTX for ewmac16_64
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast MXP for ewmac16_64
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast US10 for ewmac16_64
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast V2X for ewmac16_64
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for CORN ewmac32_128
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast CORN for ewmac32_128
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac32_128'}  Getting cross sectional forecasts for scalar calculation for ewmac32_128 over CORN, EDOLLAR, EUROSTX, MXP, US10, V2X
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EDOLLAR for ewmac32_128
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EUROSTX for ewmac32_128
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast MXP for ewmac32_128
# 2022-11-28 11:33:44 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast US10 for ewmac32_128
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast V2X for ewmac32_128
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for CORN ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast CORN for ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'forecastScaleCap', 'rule_variation_name': 'ewmac64_256'}  Getting cross sectional forecasts for scalar calculation for ewmac64_256 over CORN, EDOLLAR, EUROSTX, MXP, US10, V2X
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EDOLLAR for ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EUROSTX for ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast MXP for ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast US10 for ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast V2X for ewmac64_256
# 2022-11-28 11:33:45 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating forecast weights for CORN
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'combForecast'}  Calculating raw forecast weights for CORN
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating capped forecast for EDOLLAR carry
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating capped forecast for EUROSTX carry
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating capped forecast for MXP carry
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating capped forecast for US10 carry
# 2022-11-28 11:33:46 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating capped forecast for V2X carry
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EDOLLAR ewmac16_64
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EUROSTX ewmac16_64
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for MXP ewmac16_64
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for US10 ewmac16_64
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for V2X ewmac16_64
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EDOLLAR ewmac32_128
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EUROSTX ewmac32_128
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for MXP ewmac32_128
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for US10 ewmac32_128
# 2022-11-28 11:33:47 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for V2X ewmac32_128
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EDOLLAR ewmac64_256
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EUROSTX ewmac64_256
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for MXP ewmac64_256
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for US10 ewmac64_256
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for V2X ewmac64_256
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EDOLLAR
# 2022-11-28 11:33:48 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2022-11-28 11:33:49 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2022-11-28 11:33:49 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2022-11-28 11:33:49 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2022-11-28 11:33:49 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for CORN carry
# 2022-11-28 11:33:49 {'type': 'base_system', 'stage': 'positionSize'}  Getting vol target
# 2022-11-28 11:33:49 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating pandl for instrument forecast for CORN ewmac16_64
# 2022-11-28 11:33:50 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating pandl for instrument forecast for CORN ewmac32_128
# 2022-11-28 11:33:50 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating pandl for instrument forecast for CORN ewmac64_256
# 2022-11-28 11:33:52 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for EDOLLAR carry
# 2022-11-28 11:33:52 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating pandl for instrument forecast for EDOLLAR ewmac16_64
# 2022-11-28 11:33:53 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating pandl for instrument forecast for EDOLLAR ewmac32_128
# 2022-11-28 11:33:53 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating pandl for instrument forecast for EDOLLAR ewmac64_256
# 2022-11-28 11:33:55 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for EUROSTX carry
# 2022-11-28 11:33:55 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating pandl for instrument forecast for EUROSTX ewmac16_64
# 2022-11-28 11:33:55 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating pandl for instrument forecast for EUROSTX ewmac32_128
# 2022-11-28 11:33:55 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating pandl for instrument forecast for EUROSTX ewmac64_256
# 2022-11-28 11:33:55 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for MXP carry
# 2022-11-28 11:33:56 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating pandl for instrument forecast for MXP ewmac16_64
# 2022-11-28 11:33:56 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating pandl for instrument forecast for MXP ewmac32_128
# 2022-11-28 11:33:56 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating pandl for instrument forecast for MXP ewmac64_256
# 2022-11-28 11:33:57 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for US10 carry
# 2022-11-28 11:33:57 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating pandl for instrument forecast for US10 ewmac16_64
# 2022-11-28 11:33:58 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating pandl for instrument forecast for US10 ewmac32_128
# 2022-11-28 11:33:58 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating pandl for instrument forecast for US10 ewmac64_256
# 2022-11-28 11:34:00 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for V2X carry
# 2022-11-28 11:34:00 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating pandl for instrument forecast for V2X ewmac16_64
# 2022-11-28 11:34:00 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating pandl for instrument forecast for V2X ewmac32_128
# 2022-11-28 11:34:00 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating pandl for instrument forecast for V2X ewmac64_256
# 2022-11-28 11:34:01 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled gross returns
# 2022-11-28 11:34:01 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled turnover cost SR for CORN
# 2022-11-28 11:34:01 {'type': 'base_system', 'stage': 'combForecast'}  Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/4.0/4.0 secs left/elapsed/total)
# 2022-11-28 11:34:05 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2022-11-28 11:34:05 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating forecast div multiplier for CORN
# 2022-11-28 11:34:05 {'type': 'base_system', 'stage': 'combForecast'}  Calculating forecast correlations over CORN, EDOLLAR, EUROSTX, MXP, US10, V2X
#  [================================================================================] 100.0% Estimating correlations (0.0/0.2/0.2 secs left/elapsed/total)
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  No mapping applied for CORN
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating buffers for CORN
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating forecast method buffers for CORN
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for subsystem for instrument EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating subsystem position for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating volatility scalar for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument value vol for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument currency vol for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating combined forecast for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating forecast weights for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast'}  Calculating raw forecast weights for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled gross returns
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled turnover cost SR for EDOLLAR
# 2022-11-28 11:34:06 {'type': 'base_system', 'stage': 'combForecast'}  Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/3.9/3.9 secs left/elapsed/total)
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EDOLLAR
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating forecast div multiplier for EDOLLAR
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  No mapping applied for EDOLLAR
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating buffers for EDOLLAR
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating forecast method buffers for EDOLLAR
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for subsystem for instrument EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating subsystem position for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating volatility scalar for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument value vol for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument currency vol for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating combined forecast for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating forecast weights for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast'}  Calculating raw forecast weights for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled gross returns
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled turnover cost SR for EUROSTX
# 2022-11-28 11:34:11 {'type': 'base_system', 'stage': 'combForecast'}  Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/3.9/3.9 secs left/elapsed/total)
# 2022-11-28 11:34:15 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2022-11-28 11:34:15 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating forecast div multiplier for EUROSTX
# 2022-11-28 11:34:15 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  No mapping applied for EUROSTX
# 2022-11-28 11:34:15 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating buffers for EUROSTX
# 2022-11-28 11:34:15 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating forecast method buffers for EUROSTX
# 2022-11-28 11:34:15 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for subsystem for instrument MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating subsystem position for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating volatility scalar for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument value vol for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument currency vol for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating combined forecast for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating forecast weights for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'combForecast'}  Calculating raw forecast weights for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled gross returns
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled turnover cost SR for MXP
# 2022-11-28 11:34:16 {'type': 'base_system', 'stage': 'combForecast'}  Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/4.0/4.0 secs left/elapsed/total)
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating forecast div multiplier for MXP
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  No mapping applied for MXP
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating buffers for MXP
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating forecast method buffers for MXP
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2022-11-28 11:34:20 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for subsystem for instrument US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating subsystem position for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating volatility scalar for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument value vol for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument currency vol for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating combined forecast for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating forecast weights for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'combForecast'}  Calculating raw forecast weights for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled gross returns
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled turnover cost SR for US10
# 2022-11-28 11:34:21 {'type': 'base_system', 'stage': 'combForecast'}  Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/3.9/3.9 secs left/elapsed/total)
# 2022-11-28 11:34:25 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2022-11-28 11:34:25 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating forecast div multiplier for US10
# 2022-11-28 11:34:25 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  No mapping applied for US10
# 2022-11-28 11:34:25 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating buffers for US10
# 2022-11-28 11:34:25 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating forecast method buffers for US10
# 2022-11-28 11:34:25 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for subsystem for instrument V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating subsystem position for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating volatility scalar for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument value vol for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument currency vol for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating combined forecast for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating forecast weights for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'combForecast'}  Calculating raw forecast weights for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled gross returns
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'combForecast'}  Using pooled turnover cost SR for V2X
# 2022-11-28 11:34:26 {'type': 'base_system', 'stage': 'combForecast'}  Applying cost multiplier of 2.000000
#  [================================================================================] 100.0% Optimising weights (0.0/3.9/3.9 secs left/elapsed/total)
# 2022-11-28 11:34:30 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2022-11-28 11:34:30 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating forecast div multiplier for V2X
# 2022-11-28 11:34:30 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  No mapping applied for V2X
# 2022-11-28 11:34:30 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating buffers for V2X
# 2022-11-28 11:34:30 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating forecast method buffers for V2X
# 2022-11-28 11:34:30 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered subsystem positions
# 2022-11-28 11:34:33 {'type': 'base_system', 'stage': 'portfolio'}  Calculating raw instrument weights
# 2022-11-28 11:34:33 {'type': 'base_system', 'stage': 'portfolio'}  Using only returns of asset for gross returns
# 2022-11-28 11:34:33 {'type': 'base_system', 'stage': 'portfolio'}  Using unpooled cost SR for asset
#  [================================================================================] 100.0% Optimising weights (0.0/1.9/1.9 secs left/elapsed/total)
# 2022-11-28 11:34:36 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument div. multiplier
# 2022-11-28 11:34:36 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument correlations
#  [================================================================================] 100.0% Estimating correlations (0.0/0.1/0.1 secs left/elapsed/total)
# 2022-11-28 11:34:37 {'type': 'base_system', 'stage': 'portfolio'}  No risk overlay in config: won't apply risk scaling
# index
# 1984-03-23         NaN
# 1984-03-26         NaN
# 1984-03-27         NaN
# 1984-03-28         NaN
# 1984-03-29         NaN
#                 ...
# 2022-10-25   -5.436923
# 2022-10-26   -5.410832
# 2022-10-27   -5.346410
# 2022-10-28   -5.203956
# 2022-10-31   -5.390691
# Freq: B, Length: 10072, dtype: float64

# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()
system.rules.get_raw_forecast("EDOLLAR", "ewmac64_256")
# Out:
# 2022-11-28 11:36:55 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:36:55 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:36:55 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:36:55 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:36:55 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:36:55 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 11:36:55 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 11:36:55 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 11:36:55 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2022-11-28 11:36:55 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EDOLLAR for ewmac64_256
# 2022-11-28 11:36:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:36:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily volatility for EDOLLAR
# 2022-11-28 11:36:55 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# index
# 1984-03-23         NaN
# 1984-03-26         NaN
# 1984-03-27         NaN
# 1984-03-28         NaN
# 1984-03-29         NaN
#                 ...
# 2022-10-25   -8.476527
# 2022-10-26   -8.484119
# 2022-10-27   -8.468120
# 2022-10-28   -8.421413
# 2022-10-31   -8.630629
# Freq: B, Name: price, Length: 10072, dtype: float64

# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()
system.accounts.portfolio().stats() ## see some statistics
system.accounts.portfolio().curve().plot() ## plot an account curve
system.accounts.portfolio().percent.curve().plot() ## plot an account curve in percentage terms
system.accounts.pandl_for_instrument("US10").percent.stats() ## produce % statistics for a 10 year bond
system.accounts.pandl_for_instrument_forecast("EDOLLAR", "carry").sharpe() ## Sharpe for a specific trading rule variation
# Out:
# 2022-11-28 11:37:34 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:37:34 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:37:34 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:37:34 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:37:34 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'accounts'}  Calculating pandl for portfolio
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'positionSize'}  Getting vol target
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for instrument for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'CORN'}  Calculating notional position for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument weights
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'portfolio'}  Calculating raw instrument weights
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2022-11-28 11:37:34 {'type': 'base_system'}  Following instruments marked as not trading []
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating subsystem position for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating volatility scalar for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument value vol for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument currency vol for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily volatility for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating combined forecast for CORN
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating capped forecast for CORN carry
# 2022-11-28 11:37:34 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating raw forecast CORN for carry
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for CORN ewmac16_64
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast CORN for ewmac16_64
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for CORN ewmac32_128
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast CORN for ewmac32_128
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for CORN ewmac64_256
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast CORN for ewmac64_256
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating forecast weights for CORN
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for CORN {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating capped forecast for EDOLLAR carry
# 2022-11-28 11:37:35 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating raw forecast EDOLLAR for carry
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily volatility for EDOLLAR
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating capped forecast for EUROSTX carry
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating raw forecast EUROSTX for carry
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily volatility for EUROSTX
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating capped forecast for MXP carry
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating raw forecast MXP for carry
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily volatility for MXP
# 2022-11-28 11:37:36 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating capped forecast for US10 carry
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating raw forecast US10 for carry
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily volatility for US10
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating capped forecast for V2X carry
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating raw forecast V2X for carry
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily volatility for V2X
# 2022-11-28 11:37:37 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EDOLLAR ewmac16_64
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EDOLLAR for ewmac16_64
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EUROSTX ewmac16_64
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EUROSTX for ewmac16_64
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for MXP ewmac16_64
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast MXP for ewmac16_64
# 2022-11-28 11:37:38 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for US10 ewmac16_64
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast US10 for ewmac16_64
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for V2X ewmac16_64
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast V2X for ewmac16_64
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EDOLLAR ewmac32_128
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EDOLLAR for ewmac32_128
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EUROSTX ewmac32_128
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EUROSTX for ewmac32_128
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for MXP ewmac32_128
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast MXP for ewmac32_128
# 2022-11-28 11:37:39 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for US10 ewmac32_128
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast US10 for ewmac32_128
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for V2X ewmac32_128
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast V2X for ewmac32_128
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EDOLLAR ewmac64_256
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EDOLLAR for ewmac64_256
# 2022-11-28 11:37:40 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EUROSTX ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EUROSTX for ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for MXP ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast MXP for ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for US10 ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast US10 for ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for V2X ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast V2X for ewmac64_256
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Using fixed FDM multiplier of 1.310 for CORN
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  No mapping applied for CORN
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating subsystem position for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating volatility scalar for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument value vol for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument currency vol for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating combined forecast for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating forecast weights for EDOLLAR
# 2022-11-28 11:37:41 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for EDOLLAR {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EDOLLAR
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Using fixed FDM multiplier of 1.310 for EDOLLAR
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  No mapping applied for EDOLLAR
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating subsystem position for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating volatility scalar for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument value vol for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument currency vol for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating combined forecast for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating forecast weights for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for EUROSTX {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Using fixed FDM multiplier of 1.310 for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  No mapping applied for EUROSTX
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating subsystem position for MXP
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating volatility scalar for MXP
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument value vol for MXP
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument currency vol for MXP
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating combined forecast for MXP
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating forecast weights for MXP
# 2022-11-28 11:37:42 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for MXP {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Using fixed FDM multiplier of 1.310 for MXP
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  No mapping applied for MXP
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating subsystem position for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating volatility scalar for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument value vol for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument currency vol for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating combined forecast for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating forecast weights for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for US10 {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Using fixed FDM multiplier of 1.310 for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  No mapping applied for US10
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating subsystem position for V2X
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating volatility scalar for V2X
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument value vol for V2X
# 2022-11-28 11:37:43 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument currency vol for V2X
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating combined forecast for V2X
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating forecast weights for V2X
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for V2X {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Using fixed FDM multiplier of 1.310 for V2X
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  No mapping applied for V2X
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'portfolio'}  Using fixed diversification multiplier 1.890000
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'portfolio'}  No risk overlay in config: won't apply risk scaling
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'CORN'}  Calculating buffers for CORN
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'CORN'}  Calculating forecast method buffers for CORN
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 11:37:44 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for instrument for CORN
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for instrument for EDOLLAR
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating notional position for EDOLLAR
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating buffers for EDOLLAR
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating forecast method buffers for EDOLLAR
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for instrument for EDOLLAR
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for instrument for EUROSTX
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EUROSTX'}  Calculating notional position for EUROSTX
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EUROSTX'}  Calculating buffers for EUROSTX
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EUROSTX'}  Calculating forecast method buffers for EUROSTX
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for instrument for EUROSTX
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for instrument for MXP
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MXP'}  Calculating notional position for MXP
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MXP'}  Calculating buffers for MXP
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MXP'}  Calculating forecast method buffers for MXP
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 11:37:45 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for instrument for MXP
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'US10'}  Calculating notional position for US10
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'US10'}  Calculating buffers for US10
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'US10'}  Calculating forecast method buffers for US10
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for instrument for V2X
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'V2X'}  Calculating notional position for V2X
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'V2X'}  Calculating buffers for V2X
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'V2X'}  Calculating forecast method buffers for V2X
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 11:37:46 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for instrument for V2X
# 2022-11-28 11:37:48 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 11:37:48 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 11:37:48 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating pandl for instrument forecast for EDOLLAR carry
# 0.42852349274405466

# %%
from sysdata.config.configdata import Config
from systems.provided.futures_chapter15.basesystem import futures_system

my_config=Config("private.private_ch15_futuresconfig.yaml")
system=futures_system(config=my_config)
# Out:
# 2022-11-28 11:57:26 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:57:26 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:57:26 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:57:26 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:57:26 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:57:26 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()
new_config=system.config
# Out:
# 2022-11-28 11:58:02 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:02 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:02 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:02 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:02 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:02 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
new_config.volatility_calculation
# Out:
# {'days': 20,
#  'slow_vol_years': 10,
#  'vol_abs_min': 1e-10,
#  'proportion_of_slow_vol': 0.3,
#  'min_periods': 10,
#  'func': 'sysquant.estimators.vol.mixed_vol_calc'}

# %%
new_idm=1.1 ## new IDM

new_config.instrument_div_multiplier=new_idm

## Heres an example of how you'd change a nested parameter
## If the element doesn't yet exist in your config:

system.config.volatility_calculation=dict(days=20)

## If it does exist:
system.config.volatility_calculation['days']=20


system=futures_system(config=new_config)
# Out:
# 2022-11-28 11:58:40 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:40 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:40 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:40 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:40 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:58:40 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()

## Anything we do with the system may well be cached and will need to be cleared before it sees the new value...


new_idm=1.1 ## new IDM
system.config.instrument_div_multiplier=new_idm

## If we change anything that is nested, we need to change just one element to avoid clearing the defaults:
# So, do this:
system.config.volatility_calculation['days']=20

# Do NOT do this - it will wipe out all the other elements in the volatility_calculation dictionary:
# system.config.volatility_calculation=dict(days=20)


## The config is updated, but to reiterate anything that uses it will need to be cleared from the cache
# Out:
# 2022-11-28 11:59:09 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:59:09 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:59:09 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:59:09 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:59:09 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 11:59:09 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from sysdata.config.configdata import Config

my_config=Config("private.private_ch15_futuresconfig.yaml")

from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system(config=my_config)
# Out:
# 2022-11-28 12:01:21 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:01:21 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:01:21 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:01:21 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:01:21 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:01:21 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from systems.provided.futures_chapter15.basesystem import futures_system
system=futures_system()
new_config=system.config

new_weights=dict(SP500=0.5, KR10=0.5) ## create new weights
new_idm=1.1 ## new IDM

new_config.instrument_weights=new_weights
new_config.instrument_div_multiplier=new_idm

system=futures_system(config=new_config)
# Out:
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:13 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from systems.provided.futures_chapter15.estimatedsystem import futures_system
system=futures_system()
new_config=system.config

new_config.instruments=["SP500", "KR10"]

del(new_config.rule_variations) ## means all instruments will use all trading rules

# this stage is optional if we want to give different instruments different sets of rules
new_config.rule_variations=dict(SP500=['ewmac16_64','carry'], KR10=['ewmac32_128', 'ewmac64_256', 'carry'])

system=futures_system(config=new_config)
# Out:
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 12:25:25 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from sysdata.sim.csv_futures_sim_data import csvFuturesSimData
from systems.provided.futures_chapter15.basesystem import futures_system

data=csvFuturesSimData(csv_data_paths=dict(csvFuturesAdjustedPricesData = "private.private_ch15_basesystem.adjusted_price_data"))
system=futures_system(data=data)
# Out:
# 2022-11-28 13:24:46 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2022-11-28 13:24:46 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2022-11-28 13:24:46 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2022-11-28 13:24:46 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2022-11-28 13:24:46 {'type': 'base_system', 'stage': 'config'}  Adding config defaults

# %%
from systems.provided.futures_chapter15.basesystem import futures_system

system = futures_system(log_level="on")
system.accounts.portfolio().sharpe() ## does a whole bunch of calculations that will be saved in the cache
# Out:
# 2022-11-28 13:26:24 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:26:24 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:26:24 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:26:24 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:26:24 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'accounts'}  Calculating pandl for portfolio
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'positionSize'}  Getting vol target
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for instrument for CORN
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'CORN'}  Calculating notional position for CORN
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'portfolio'}  Calculating instrument weights
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'portfolio'}  Calculating raw instrument weights
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments are marked as 'bad_markets':  ['BAD_EXAMPLE']
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments have restricted trading:  ['RESTRICTED_EXAMPLE']
# 2022-11-28 13:26:24 {'type': 'base_system'}  Following instruments marked as not trading []
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating subsystem position for CORN
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating volatility scalar for CORN
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument value vol for CORN
# 2022-11-28 13:26:24 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'CORN'}  Calculating instrument currency vol for CORN
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily volatility for CORN
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating combined forecast for CORN
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating capped forecast for CORN carry
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'carry'}  Calculating raw forecast CORN for carry
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for CORN ewmac16_64
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast CORN for ewmac16_64
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for CORN ewmac32_128
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast CORN for ewmac32_128
# 2022-11-28 13:26:25 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for CORN ewmac64_256
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'CORN', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast CORN for ewmac64_256
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'CORN'}  Calculating daily prices for CORN
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Calculating forecast weights for CORN
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for CORN {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating capped forecast for EDOLLAR carry
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'carry'}  Calculating raw forecast EDOLLAR for carry
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily volatility for EDOLLAR
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating capped forecast for EUROSTX carry
# 2022-11-28 13:26:26 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'carry'}  Calculating raw forecast EUROSTX for carry
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily volatility for EUROSTX
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating capped forecast for MXP carry
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'carry'}  Calculating raw forecast MXP for carry
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily volatility for MXP
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating capped forecast for US10 carry
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'carry'}  Calculating raw forecast US10 for carry
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily volatility for US10
# 2022-11-28 13:26:27 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 13:26:28 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating capped forecast for V2X carry
# 2022-11-28 13:26:28 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'carry'}  Calculating raw forecast V2X for carry
# 2022-11-28 13:26:28 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily volatility for V2X
# 2022-11-28 13:26:28 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EDOLLAR ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EDOLLAR for ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for EUROSTX ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast EUROSTX for ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for MXP ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast MXP for ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for US10 ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast US10 for ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating capped forecast for V2X ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac16_64'}  Calculating raw forecast V2X for ewmac16_64
# 2022-11-28 13:26:29 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EDOLLAR ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EDOLLAR for ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for EUROSTX ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast EUROSTX for ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for MXP ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast MXP for ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for US10 ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast US10 for ewmac32_128
# 2022-11-28 13:26:30 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating capped forecast for V2X ewmac32_128
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac32_128'}  Calculating raw forecast V2X for ewmac32_128
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EDOLLAR ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EDOLLAR', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EDOLLAR for ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EDOLLAR'}  Calculating daily prices for EDOLLAR
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for EUROSTX ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'EUROSTX', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast EUROSTX for ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'EUROSTX'}  Calculating daily prices for EUROSTX
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for MXP ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'MXP', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast MXP for ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'MXP'}  Calculating daily prices for MXP
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for US10 ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'US10', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast US10 for ewmac64_256
# 2022-11-28 13:26:31 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'US10'}  Calculating daily prices for US10
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'forecastScaleCap', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating capped forecast for V2X ewmac64_256
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'rules', 'instrument_code': 'V2X', 'rule_variation_name': 'ewmac64_256'}  Calculating raw forecast V2X for ewmac64_256
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'rawdata', 'instrument_code': 'V2X'}  Calculating daily prices for V2X
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for CORN
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  Using fixed FDM multiplier of 1.310 for CORN
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'CORN'}  No mapping applied for CORN
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating subsystem position for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating volatility scalar for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument value vol for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EDOLLAR'}  Calculating instrument currency vol for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating combined forecast for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Calculating forecast weights for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for EDOLLAR {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  Using fixed FDM multiplier of 1.310 for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EDOLLAR'}  No mapping applied for EDOLLAR
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating subsystem position for EUROSTX
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating volatility scalar for EUROSTX
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument value vol for EUROSTX
# 2022-11-28 13:26:32 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'EUROSTX'}  Calculating instrument currency vol for EUROSTX
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating combined forecast for EUROSTX
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Calculating forecast weights for EUROSTX
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for EUROSTX {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for EUROSTX
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  Using fixed FDM multiplier of 1.310 for EUROSTX
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'EUROSTX'}  No mapping applied for EUROSTX
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating subsystem position for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating volatility scalar for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument value vol for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'MXP'}  Calculating instrument currency vol for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating combined forecast for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Calculating forecast weights for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for MXP {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  Using fixed FDM multiplier of 1.310 for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'MXP'}  No mapping applied for MXP
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating subsystem position for US10
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating volatility scalar for US10
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument value vol for US10
# 2022-11-28 13:26:33 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'US10'}  Calculating instrument currency vol for US10
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating combined forecast for US10
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Calculating forecast weights for US10
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for US10 {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for US10
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  Using fixed FDM multiplier of 1.310 for US10
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'US10'}  No mapping applied for US10
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating subsystem position for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating volatility scalar for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument value vol for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'positionSize', 'instrument_code': 'V2X'}  Calculating instrument currency vol for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating combined forecast for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Calculating forecast weights for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast'}  Non-nested dict of forecast weights for V2X {'ewmac16_64': 0.21, 'ewmac32_128': 0.08, 'ewmac64_256': 0.21, 'carry': 0.5}: weights the same for all instruments
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Only this set of rules ['carry', 'ewmac16_64', 'ewmac32_128', 'ewmac64_256'] is cheap enough to trade for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  Using fixed FDM multiplier of 1.310 for V2X
# 2022-11-28 13:26:34 {'type': 'base_system', 'stage': 'combForecast', 'instrument_code': 'V2X'}  No mapping applied for V2X
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio'}  Using fixed diversification multiplier 1.890000
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio'}  No risk overlay in config: won't apply risk scaling
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'CORN'}  Calculating buffers for CORN
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'CORN'}  Calculating forecast method buffers for CORN
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for instrument for CORN
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for instrument for EDOLLAR
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating notional position for EDOLLAR
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating buffers for EDOLLAR
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EDOLLAR'}  Calculating forecast method buffers for EDOLLAR
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 13:26:35 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for instrument for EDOLLAR
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for instrument for EUROSTX
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EUROSTX'}  Calculating notional position for EUROSTX
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EUROSTX'}  Calculating buffers for EUROSTX
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'EUROSTX'}  Calculating forecast method buffers for EUROSTX
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for instrument for EUROSTX
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for instrument for MXP
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MXP'}  Calculating notional position for MXP
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MXP'}  Calculating buffers for MXP
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'MXP'}  Calculating forecast method buffers for MXP
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for instrument for MXP
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'US10'}  Calculating notional position for US10
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'US10'}  Calculating buffers for US10
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'US10'}  Calculating forecast method buffers for US10
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 13:26:36 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 13:26:37 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for instrument for V2X
# 2022-11-28 13:26:37 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'V2X'}  Calculating notional position for V2X
# 2022-11-28 13:26:37 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'V2X'}  Calculating buffers for V2X
# 2022-11-28 13:26:37 {'type': 'base_system', 'stage': 'portfolio', 'instrument_code': 'V2X'}  Calculating forecast method buffers for V2X
# 2022-11-28 13:26:37 {'type': 'base_system', 'stage': 'accounts'}  Calculating buffered positions
# 2022-11-28 13:26:37 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for instrument for V2X
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_720143/2246951999.py in <module>
#       4 system.accounts.portfolio().sharpe() ## does a whole bunch of calculations that will be saved in the cache
#       5
# ----> 6 system.cache.pickle("private.test20221128.system.pck") ## use any file extension you like
#
# ~/pysystemtrade/systems/system_cache.py in pickle(self, relativefilename)
#     215         cache_to_pickle_as_dict = cache_to_pickle.as_dict()
#     216
# --> 217         with open(filename, "wb+") as fhandle:
#     218             pickle.dump(cache_to_pickle_as_dict, fhandle)
#     219
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/arto/pysystemtrade/private/test20221128/system.pck'

# %%
system.cache.pickle("private.test20221128.system.pck") ## use any file extension you like

# %%
## In a new session
from systems.provided.futures_chapter15.basesystem import futures_system

system = futures_system(log_level="on")
system.cache.unpickle("private.test20221128.system.pck")

## this will run much faster and reuse previous calculations
# only complex accounting p&l objects aren't saved in the cache
system.accounts.portfolio().sharpe()
# Out:
# 2022-11-28 13:29:10 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:29:10 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:29:10 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:29:10 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:29:10 {'type': 'csvFuturesSimData'} [Warning] No datapaths provided for .csv, will use defaults  (may break in production, should be fine in sim)
# 2022-11-28 13:29:10 {'type': 'base_system', 'stage': 'config'}  Adding config defaults
# 2022-11-28 13:29:10 {'type': 'base_system', 'stage': 'accounts'}  Calculating pandl for portfolio
# 2022-11-28 13:29:10 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for instrument for CORN
# 2022-11-28 13:29:10 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'CORN'}  Calculating pandl for instrument for CORN
# 2022-11-28 13:29:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for instrument for EDOLLAR
# 2022-11-28 13:29:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EDOLLAR'}  Calculating pandl for instrument for EDOLLAR
# 2022-11-28 13:29:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for instrument for EUROSTX
# 2022-11-28 13:29:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'EUROSTX'}  Calculating pandl for instrument for EUROSTX
# 2022-11-28 13:29:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for instrument for MXP
# 2022-11-28 13:29:11 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'MXP'}  Calculating pandl for instrument for MXP
# 2022-11-28 13:29:12 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 13:29:12 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'US10'}  Calculating pandl for instrument for US10
# 2022-11-28 13:29:12 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for instrument for V2X
# 2022-11-28 13:29:12 {'type': 'base_system', 'stage': 'accounts', 'instrument_code': 'V2X'}  Calculating pandl for instrument for V2X
# 0.4601414712575453
